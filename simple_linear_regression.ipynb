# %% [markdown]
# <a href="https://colab.research.google.com/github/YajanSharma/Aenerative-ai/blob/main/simple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# simple lenear regression
# y = mx + b
# steps
# import library
# import data(from google drive to google colab)
# data analysis
#              find the iniformation of data
#              find the null value
#              how does the data looks like mathematically
# find the independent and dependent feature
#         cgpa(x)          package(y)
# fuction = train_test_spilt--- it is used to split the data
# import the regression model
# train the model
# model prediction

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/drive/MyDrive/data/placement (1).csv")
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
# find the numner of rows and column
df.shape
# Out:
# (200, 2)

# %%
# find the information of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
# find the null value in the dataset
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
# find the independent feature and dependent feature
x=df.iloc[:,0].values
y=df.iloc[:,1].values
x
# Out:
# array([6.89, 5.12, 7.82, 7.42, 6.94, 7.89, 6.73, 6.75, 6.09, 8.31, 5.32,
#        6.61, 8.94, 6.93, 7.73, 7.25, 6.84, 5.38, 6.94, 7.48, 7.28, 6.85,
#        6.14, 6.19, 6.53, 7.28, 8.31, 5.42, 5.94, 7.15, 7.36, 8.1 , 6.96,
#        6.35, 7.34, 6.87, 5.99, 5.9 , 8.62, 7.43, 9.38, 6.89, 5.95, 7.66,
#        5.09, 7.87, 6.07, 5.84, 8.63, 8.87, 9.58, 9.26, 8.37, 6.47, 6.86,
#        8.2 , 5.84, 6.6 , 6.92, 7.56, 5.61, 5.48, 6.34, 9.16, 7.36, 7.6 ,
#        5.11, 6.51, 7.56, 7.3 , 5.79, 7.47, 7.78, 8.44, 6.85, 6.97, 6.94,
#        8.99, 6.59, 7.18, 7.63, 6.1 , 5.58, 8.44, 4.26, 4.79, 7.61, 8.09,
#        4.73, 6.42, 7.11, 6.22, 7.9 , 6.79, 5.83, 6.63, 7.11, 5.98, 7.69,
#        6.61, 7.95, 6.71, 5.13, 7.05, 7.62, 6.66, 6.13, 6.33, 7.76, 7.77,
#        8.18, 5.42, 8.58, 6.94, 5.84, 8.35, 9.04, 7.12, 7.4 , 7.39, 5.23,
#        6.5 , 5.12, 5.1 , 6.06, 7.33, 5.91, 6.78, 7.93, 7.29, 6.68, 6.37,
#        5.84, 6.05, 7.2 , 6.1 , 5.64, 7.14, 7.91, 7.19, 7.91, 6.76, 6.93,
# ...

# %%
# split the data into ttain and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train
# Out:
# array([7.18, 7.21, 8.62, 6.53, 5.12, 6.93, 7.15, 7.48, 4.85, 7.61, 5.84,
#        6.75, 7.89, 5.91, 7.12, 8.44, 7.91, 7.69, 6.93, 7.11, 9.31, 5.98,
#        8.1 , 8.94, 6.87, 7.39, 5.95, 8.11, 7.11, 5.64, 9.26, 6.78, 5.53,
#        6.89, 7.4 , 6.94, 8.31, 7.19, 7.95, 5.42, 7.82, 8.99, 6.07, 6.26,
#        7.28, 4.79, 7.3 , 5.99, 6.19, 5.48, 6.14, 6.76, 6.71, 6.35, 6.61,
#        7.89, 8.71, 6.73, 5.42, 5.23, 6.94, 6.96, 6.93, 5.84, 7.77, 6.17,
#        5.32, 6.34, 8.58, 6.07, 8.6 , 6.89, 7.63, 7.94, 5.79, 5.1 , 7.36,
#        5.09, 8.93, 5.94, 9.38, 7.76, 6.98, 7.38, 7.28, 6.19, 7.88, 5.66,
#        6.1 , 7.43, 8.65, 5.84, 5.83, 7.08, 7.66, 7.91, 7.42, 6.66, 6.47,
#        6.05, 6.19, 8.15, 6.31, 8.87, 7.63, 7.34, 6.75, 8.18, 6.22, 8.44,
#        6.29, 8.22, 6.42, 6.09, 6.93, 7.56, 8.01, 6.37, 5.38, 7.78, 7.04,
#        7.2 , 8.13, 7.28, 9.16, 6.86, 6.33, 9.58, 5.89, 6.92, 8.63, 4.73,
#        6.85, 6.6 , 7.13, 8.25, 7.29, 5.9 , 6.47, 4.57, 5.12, 8.37, 8.28,
# ...

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train.reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
# coefficent
m = model.coef_
print(m[0])
# Out:
# 0.5742564727019197

# %%
# intercept
b = model.intercept_
print(b)
# Out:
# -1.0270069374542108

# %%
cgpa = 9.5
package = m*cgpa + b
print(package)
# Out:
# [4.42842955]

# %%
y_pred = model.predict(x_test.reshape(-1,1))
y_pred, y_test
# Out:
# (array([2.78031348, 3.13635249, 3.1995207 , 2.38981908, 3.52684689,
#         3.76803461, 3.16506531, 2.54486832, 3.17655044, 3.4923915 ,
#         1.90744364, 2.34962112, 3.6876387 , 2.75734322, 3.47516381,
#         3.04447145, 2.32665086, 3.20526327, 2.17734418, 3.314372  ,
#         2.45298729, 2.90090734, 3.32011456, 2.87219451, 3.33734226,
#         2.19457187, 1.41932564, 2.7114027 , 3.18229301, 2.32665086,
#         3.74506435, 2.95833298, 3.68189614, 2.97556068, 2.59080884,
#         3.34882738, 2.47595755, 3.07318428, 4.17575671, 2.95833298]),
#  array([2.79, 3.23, 3.26, 3.04, 3.34, 4.21, 2.94, 2.87, 2.99, 3.58, 1.63,
#         2.08, 4.08, 2.21, 3.47, 3.64, 2.74, 3.08, 2.17, 2.99, 2.31, 2.35,
#         3.4 , 3.08, 3.81, 2.19, 1.53, 2.89, 3.16, 2.48, 3.51, 2.98, 3.39,
#         3.28, 2.73, 3.74, 2.6 , 3.13, 3.82, 3.15]))

# %%
import matplotlib.pyplot as plt
plt.scatter(df["cgpa"], df["package"])
plt.plot(x_train, m*x_train + b, color="red")
plt.xlabel("cgpa")
plt.ylabel("package")
plt.show()
